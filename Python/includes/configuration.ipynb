# %% [markdown]
# ## Holds Application Specific Configurations

# %%
ingestionPipelinePath = f"/ingestion/dataengineering/gsg/"
restApiEndpoint = "https://bikeindex.org/api/v3/search"

landingPath = ingestionPipelinePath + "raw/"
stagingPath = ingestionPipelinePath + "stage/"
processedPath = ingestionPipelinePath + "processed/"

# %% [markdown]
# ### Create and Use database as Metastore

# %%
spark.sql(f"CREATE DATABASE IF NOT EXISTS gsg_ingestion")

spark.sql(f"USE gsg_ingestion")
# Out:
# Out[2]: DataFrame[]

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
